# %% [markdown]
# ### PENDING:
#
# 1. Retain records when player out of game
# 2. Add:
#     - records of faced-off cards and revise prob of lie
#     - when only 2 players remain, 1 player has 1 card remains, the other always bust despite of the style & risk
# 3. Make modular function for moves
# 4. Bootstrap
# 5. Data viz
# 6. Interactive with real human playing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# Set up game:

# %%
moves = ["bust", "pass", "true", "lie"]

# %% [markdown]
# Set up player

# %%
player = np.array(["Thanos", "Ironman", "Batman", "Human"])
print("Number of player must be divided by 4") if len(player) % 4 != 0 else len(player)
# Out:
# 4

# %% [markdown]
# Set up honesty level for each player. Honesty runs from 0 to 1, with 0 being always lie and 1 being always honest

# %%
honesty = np.random.rand(4)
honesty
# Out:
# array([0.49471129, 0.78015494, 0.77661183, 0.01024954])

# %% [markdown]
# ### Set up style of player:
#
# yolo: This player makes a move simply based on flipping a coin. If the coin tells him to play true while he does not have the card, he will just pass the move
#
# safe: this player will only play true or pass. He nevers bust or lie to avoid the risk of picking up the cards.
#
# thinker: this player analyses all players and keep track of faced-off cards, and consider risks and rewards before making a move

# %%
style = np.random.choice(["yolo", "thinker", "safe"], replace = True, size = 4)
style
# Out:
# array(['thinker', 'thinker', 'yolo', 'yolo'], dtype='<U7')

# %% [markdown]
# Reward and penalty matrix for current player:
#
# ![table1.png](table1.png)

# %% [markdown]
# Flow of codes for each game: assemble deck, split cards to each player, play.
#
# ### Assign cards for each player

# %%
ranks = np.append(np.arange(2,11), ["A", "J", "Q", "K"])
suit_num = 4
deck_num = len(player)/suit_num
deck = np.repeat(ranks, 4*deck_num)
card_num = len(deck)/len(player)
cards = []
for i in range(1,5):
    idx = np.random.choice(range(0,len(deck)), replace = False, size = int(card_num))
    cards.append(np.sort(deck[idx]))
    deck = np.delete(deck, idx)
cards
# Out:
# [array(['2', '2', '4', '5', '7', '7', '9', 'A', 'A', 'A', 'K', 'K', 'Q'],
#        dtype='<U11'),
#  array(['10', '3', '3', '4', '5', '5', '5', '6', '8', 'A', 'J', 'K', 'Q'],
#        dtype='<U11'),
#  array(['10', '3', '6', '6', '7', '8', '8', '8', '9', '9', 'J', 'K', 'Q'],
#        dtype='<U11'),
#  array(['10', '10', '2', '2', '3', '4', '4', '6', '7', '9', 'J', 'J', 'Q'],
#        dtype='<U11')]

# %%
ranks = np.append(np.arange(2,11), ["A", "J", "Q", "K"])
suit_num = 4
deck_num = len(player)/suit_num
deck = np.repeat(ranks, 4*deck_num)
card_num = len(deck)/len(player)
cards = []
for i in range(1,5):
    idx = np.random.choice(range(0,len(deck)), replace = False, size = int(card_num))
    cards.append(np.sort(deck[idx]))
    deck = np.delete(deck, idx)

player_remain = player
player_num = len(player_remain)
#Initiate round number:
round_num = 1

#Initiate placeholder for winners:
winner = []

#Initiate placehoder for round winner:
round_winner = ""
anchor = None

#Initiate tracking of picked up cards in row of 3+
r3_records = [[],[],[],[]]

#Initiate probability of lying and probability of bust
prob_lie = np.repeat(0.5, player_num)
prob_bust = np.repeat(0.5, player_num)

#Initiate placehoder for moves played
moves_records = np.zeros((4, 4)) 
    #row 1 is times when lie is exposed, row 3 is number of place move 
    #row 3 is times when bust is made, row 4 is number of moves

#Initiate tracking of safe cards played by round starter after each failed bust
safe_num = 0

#Game stops when only 1 player remains:
while player_num > 1:
    #For each round:
    
    #initiate number of 'pass' move and initiate status of 'bust' move ('False' means no 'bust' happens yet)
    pass_num = 0
    bust = False
    
    #Initiate string of placed cards:
    place = []
    
    #Index of players for current round
    player_idx = np.where(np.isin(player, player_remain))[0]
    #First player of round 1 is random, of 2nd round onwards is the previous round's winner:
    first_player = np.random.choice(range(len(player))) if round_num == 1 else np.where(player == round_winner)[0][0]
    print("ROUND ", round_num)
    print("first player:", player[first_player])
    
    #First move of round is always to place a card:
    idx = np.random.choice(range(len(cards[first_player])))    
    place.append(cards[first_player][idx]) 
    cards[first_player] = np.delete(cards[first_player], idx)
    idx = np.random.choice(np.where(ranks != place[-1])[0])
    call = ranks[idx] if (honesty[first_player] < 0.5) else place[-1]
    moves_records[1,first_player] += 1
    moves_records[3,first_player] += 1
    print("place: ", place, "call: ", call)
    
    #Initiate string of players:
    previous_player = first_player
    remain = np.where(~np.isin(player, winner))[0]
    remain = np.roll(remain, len(remain)-np.where(remain == previous_player)[0][0])               
    current_player = remain[1]
    next_player = remain[2] if player_num >2 else remain[0]    
    
    #Initiate count of cards cleared:
    cleared_num = [0, 0, 0, 0]
    cleared_num[first_player] += 1
    
    #Round stops when all other players play 'pass' move sequentially or when there is a bust
    while (pass_num < (player_num - 1)) & (bust == False):
        #update probability of lie and bust
        if moves_records[1,previous_player] != 0:
            prob_lie[previous_player] = moves_records[0,previous_player]/moves_records[1,previous_player] 
        if moves_records[3,current_player] != 0:
            prob_bust[current_player] = moves_records[2,current_player]/moves_records[3,current_player]
        #estimated reward and penalty
        r3_num = np.nanmean(r3_records[current_player]) if len(r3_records[current_player]) !=0 else 0
        cleared_num[current_player] += 1          
        
        reward_bust = np.array([r3_num*(1-prob_lie[previous_player]), len(place)*prob_lie[previous_player], 0, 0])
        reward_pass = np.array([0,0, 0, 0])
        reward_true = np.array([0, 0, 
                                (cleared_num[current_player] + safe_num)*prob_bust[next_player] if call in cards[current_player] else 0,
                                (cleared_num[current_player])*(1-prob_bust[next_player]) if call in cards[current_player] else 0])
        reward_lie = np.array([0, 0, 
                               r3_num*prob_bust[next_player], 
                               cleared_num[current_player]*(1-prob_bust[next_player])])
        
        penalty_bust = np.array([len(place)*(1-prob_lie[previous_player]), 0, 0, 0])
        penalty_pass = np.array([0, 0, 0, 0])
        penalty_true = np.array([0, 0, 0, 0])
        penalty_lie = np.array([0, 0, len(place)*prob_bust[next_player], 0])
        
        net_reward = [reward_bust - penalty_bust, reward_pass - penalty_pass,
                      reward_true - penalty_true, reward_lie - penalty_lie]       
        
        #next player play a move:
        if style[current_player] == "yolo":
            move = np.random.choice(range(len(moves)))
            if move == 0: #bust
                bust = True
                moves_records[2,current_player] += 1 #update bust move to record
                if place[-1] == call:
                    cards[current_player] = np.append(cards[current_player], place)  
                else: 
                    if anchor is not None: busted_player = anchor  
                    else: busted_player = previous_player
                    cards[busted_player] = np.append(cards[busted_player], place)
                    moves_records[0,busted_player] += 1 #update lie exposed to record
                temp = pd.Series(place).value_counts()
                r3_records[current_player].append(temp[np.where(temp >= 3)[0]].sum())
                pass_num = 0           
            elif move == 1: #pass
                pass_num += 1
            elif move == 2: #true
                #if the desired card is not available, play 'pass' move:
                if call in cards[current_player]:
                    place.append(call)
                    cards[current_player] = np.delete(cards[current_player], 
                                                      np.where(cards[current_player] == call)[0][0])
                    pass_num = 0
                else:
                    pass_num += 1
                    move = 1
            else:
                #place a 'lie' move
                idx = np.random.choice(np.where(cards[current_player]!=call)[0])                
                place.append(cards[current_player][idx])
                cards[current_player] = np.delete(cards[current_player], idx)
                pass_num = 0
        elif style[current_player] == "thinker":
            move = np.where(net_reward == np.amax(net_reward))[0][0]
            if move == 0:
                bust = True
                moves_records[2,current_player] += 1 #update bust move to record
                if place[-1] == call:
                    cards[current_player] = np.append(cards[current_player], place)  
                else: 
                    if anchor is not None: busted_player = anchor  
                    else: busted_player = previous_player
                    cards[busted_player] = np.append(cards[busted_player], place)
                    moves_records[0,busted_player] += 1 #update lie exposed to record
                temp = pd.Series(place).value_counts()
                r3_records[current_player].append(temp[np.where(temp >= 3)[0]].sum())
                pass_num = 0 
            elif move == 1:
                pass_num += 1
            elif move == 2: #true or pass
                #if the desired card is not available, play 'pass' move:
                if call in cards[current_player]: #true
                    place.append(call)
                    cards[current_player] = np.delete(cards[current_player], 
                                                      np.where(cards[current_player] == call)[0][0])
                    pass_num = 0
                else: #pass
                    pass_num += 1
                    move = 1
            else: #lie
                idx = np.random.choice(np.where(cards[current_player]!=call)[0])                
                place.append(cards[current_player][idx])
                cards[current_player] = np.delete(cards[current_player], idx)
                pass_num = 0
        else: #safe style
            #if the desired card is not available, play 'pass' move:
            if call in cards[current_player]: #true
                place.append(call)
                cards[current_player] = np.delete(cards[current_player], np.where(cards[current_player] == call)[0][0])
                pass_num = 0
                move = 2
            else: #pass
                pass_num += 1
                move = 1
        moves_records[3,current_player] += 1
        print(player[current_player],"-",style[current_player],", plays", moves[move])
        print("place:", place)

        #anchor previous player whose fate is on hold
        if pass_num == 1: anchor = previous_player
        
        #Increment safe cards played by round starters after a failed bust
        if current_player == first_player & bust == False: safe_num += 1       
           
        #count cards of players remain in the round
        card_count = [len(i) for i in cards]

#RECHECK THESE
        remain = np.where(~np.isin(player, winner))[0]
        if (move == 0) & (place[-1] != call):
            remain = np.roll(remain, len(remain)-np.where(remain == busted_player)[0][0])
        elif move == 1:
            remain = np.roll(remain, len(remain)-np.where(remain == anchor)[0][0])
        else:
            remain = np.roll(remain, len(remain)-np.where(remain == previous_player)[0][0])        

        #Update the round winner:
        if bust == True:
            idx_win = busted_player if place[-1] == call else current_player
            if len(cards[idx_win]) == 0: idx_win = remain[1]  
            round_winner = player[idx_win]
        if pass_num == player_num - 1:
            if anchor is not None: idx_win = anchor
            if len(cards[idx_win]) == 0: idx_win = remain[1]
            round_winner = player[idx_win]
        
        #if pass_num == player_num - 1:
        #    if current_player - pass_num >=0:
        #        idx_win = current_player - pass_num 
        #    else:
        #        idx_win = current_player - pass_num + player_num
        #    if len(cards[idx_win]) == 0:
        #        idx_win = idx_win + 1 if (idx_win < player_num - 1) else 0
        #    round_winner = player[idx_win]
        print("\t",cards[current_player])
        print("\t player num: ", player_num, ", round winner: ", round_winner)
        print("\t anchor: ", player[anchor] if anchor is not None else "none", 
              ", busted: ", player[busted_player])        
        #remove player with 0 cards out of game
        if anchor is not None:
            if (card_count[anchor] == 0) & (pass_num == player_num - 1): winner.append(player[anchor])
            if (card_count[anchor] == 0) & (move > 1): winner.append(player[anchor])
            if (card_count[anchor] == 0) & (move == 0): winner.append(player[anchor])
            #reset anchor when his fate is no longer on hold
            if (player[anchor] in winner) | (move != 1) | (pass_num == player_num - 1): anchor = None
        if (move > 1) & (card_count[previous_player] == 0): winner.append(player[previous_player])
        if (move == 0) & (card_count[previous_player] == 0): winner.append(player[previous_player])
              
        player_num = len(player) - len(winner)        
        if player_num == 1: bust = True
        
        #increment of the position of player
        previous_player = current_player 
        remain = np.where(~np.isin(player, winner))[0]
        remain = np.roll(remain, len(remain)-np.where(remain == previous_player)[0][0])               
        current_player = remain[1] if player_num >1 else previous_player
        next_player = remain[2] if player_num >2 else remain[0]

        print("\t winner: ", winner, ", remain:", player[remain])
    #Update round number
    round_num += 1
# Out:
# ROUND  1
# first player: Ironman
# place:  ['10'] call:  10
# Batman - yolo , plays bust
# place: ['10']
# 	 ['2' '3' '4' '5' '6' '7' 'A' 'J' 'J' 'J' 'K' 'K' 'Q' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Ironman
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  2
# first player: Ironman
# place:  ['K'] call:  K
# Batman - yolo , plays true
# place: ['K', 'K']
# 	 ['2' '3' '4' '5' '6' '7' 'A' 'J' 'J' 'J' 'K' 'Q' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Ironman
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays pass
# place: ['K', 'K']
# 	 ['10' '3' '6' '6' '7' '8' '8' '8' '9' 'A' 'A' 'J' 'Q']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Batman , busted:  Ironman
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays bust
# place: ['K', 'K']
# 	 ['10' '10' '2' '2' '2' '3' '4' '5' '5' '7' '8' '9' 'K' 'K' 'K']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Batman , busted:  Ironman
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# ROUND  3
# first player: Ironman
# place:  ['Q'] call:  Q
# Batman - yolo , plays lie
# place: ['Q', '4']
# 	 ['2' '3' '5' '6' '7' 'A' 'J' 'J' 'J' 'K' 'Q' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Ironman
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays bust
# place: ['Q', '4']
# 	 ['10' '3' '6' '6' '7' '8' '8' '8' '9' 'A' 'A' 'J' 'Q']
# 	 player num:  4 , round winner:  Human
# 	 anchor:  none , busted:  Batman
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# ROUND  4
# first player: Human
# place:  ['8'] call:  6
# Thanos - thinker , plays lie
# place: ['8', '7']
# 	 ['10' '10' '2' '2' '2' '3' '4' '5' '5' '8' '9' 'K' 'K' 'K']
# 	 player num:  4 , round winner:  Human
# 	 anchor:  none , busted:  Batman
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['8', '7']
# 	 ['3' '4' '4' '5' '6' '7' '9' '9' 'A' 'Q']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  5
# first player: Ironman
# place:  ['4'] call:  4
# Batman - yolo , plays bust
# place: ['4']
# 	 ['2' '3' '5' '6' '7' 'A' 'J' 'J' 'J' 'K' 'Q' '10' 'Q' '4' '4']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  6
# first player: Thanos
# place:  ['2'] call:  8
# Ironman - thinker , plays bust
# place: ['2']
# 	 ['3' '4' '5' '6' '7' '9' '9' 'A' 'Q']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  7
# first player: Ironman
# place:  ['5'] call:  5
# Batman - yolo , plays bust
# place: ['5']
# 	 ['2' '3' '5' '6' '7' 'A' 'J' 'J' 'J' 'K' 'Q' '10' 'Q' '4' '4' '5']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  8
# first player: Thanos
# place:  ['7'] call:  10
# Ironman - thinker , plays bust
# place: ['7']
# 	 ['3' '4' '6' '7' '9' '9' 'A' 'Q']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  9
# first player: Ironman
# place:  ['9'] call:  9
# Batman - yolo , plays lie
# place: ['9', 'A']
# 	 ['2' '3' '5' '6' '7' 'J' 'J' 'J' 'K' 'Q' '10' 'Q' '4' '4' '5']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays pass
# place: ['9', 'A']
# 	 ['10' '3' '6' '6' '7' '8' '8' '9' 'A' 'A' 'J' 'Q']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays true
# place: ['9', 'A', '9']
# 	 ['10' '10' '2' '2' '3' '4' '5' '5' '8' 'K' 'K' 'K' '8' '2' '7']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['9', 'A', '9']
# 	 ['3' '4' '6' '7' '9' 'A' 'Q' '9' 'A' '9']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  10
# first player: Thanos
# place:  ['10'] call:  6
# Ironman - thinker , plays true
# place: ['10', '6']
# 	 ['3' '4' '7' '9' 'A' 'Q' '9' 'A' '9']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays pass
# place: ['10', '6']
# 	 ['2' '3' '5' '6' '7' 'J' 'J' 'J' 'K' 'Q' '10' 'Q' '4' '4' '5']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays true
# place: ['10', '6', '6']
# 	 ['10' '3' '6' '7' '8' '8' '9' 'A' 'A' 'J' 'Q']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays lie
# place: ['10', '6', '6', '10']
# 	 ['2' '2' '3' '4' '5' '5' '8' 'K' 'K' 'K' '8' '2' '7']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['10', '6', '6', '10']
# 	 ['3' '4' '7' '9' 'A' 'Q' '9' 'A' '9']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  11
# first player: Ironman
# place:  ['Q'] call:  Q
# Batman - yolo , plays lie
# place: ['Q', '5']
# 	 ['2' '3' '5' '6' '7' 'J' 'J' 'J' 'K' 'Q' '10' 'Q' '4' '4']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays bust
# place: ['Q', '5']
# 	 ['10' '3' '6' '7' '8' '8' '9' 'A' 'A' 'J' 'Q']
# 	 player num:  4 , round winner:  Human
# 	 anchor:  none , busted:  Batman
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# ROUND  12
# first player: Human
# place:  ['3'] call:  4
# Thanos - thinker , plays true
# place: ['3', '4']
# 	 ['2' '2' '3' '5' '5' '8' 'K' 'K' 'K' '8' '2' '7' '10' '6' '6' '10']
# 	 player num:  4 , round winner:  Human
# 	 anchor:  none , busted:  Batman
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['3', '4']
# 	 ['3' '4' '7' '9' 'A' '9' 'A' '9' '3' '4']
# 	 player num:  4 , round winner:  Batman
# 	 anchor:  none , busted:  Batman
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  13
# first player: Batman
# place:  ['10'] call:  10
# Human - yolo , plays pass
# place: ['10']
# 	 ['10' '6' '7' '8' '8' '9' 'A' 'A' 'J' 'Q']
# 	 player num:  4 , round winner:  Batman
# 	 anchor:  Batman , busted:  Batman
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays true
# place: ['10', '10']
# 	 ['2' '2' '3' '5' '5' '8' 'K' 'K' 'K' '8' '2' '7' '6' '6' '10']
# 	 player num:  4 , round winner:  Batman
# 	 anchor:  Batman , busted:  Batman
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['10', '10']
# 	 ['3' '4' '7' '9' 'A' '9' 'A' '9' '3' '4' '10' '10']
# 	 player num:  4 , round winner:  Batman
# 	 anchor:  none , busted:  Batman
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  14
# first player: Batman
# place:  ['3'] call:  3
# Human - yolo , plays pass
# place: ['3']
# 	 ['10' '6' '7' '8' '8' '9' 'A' 'A' 'J' 'Q']
# 	 player num:  4 , round winner:  Batman
# 	 anchor:  Batman , busted:  Batman
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays true
# place: ['3', '3']
# 	 ['2' '2' '5' '5' '8' 'K' 'K' 'K' '8' '2' '7' '6' '6' '10']
# 	 player num:  4 , round winner:  Batman
# 	 anchor:  Batman , busted:  Batman
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays true
# place: ['3', '3', '3']
# 	 ['4' '7' '9' 'A' '9' 'A' '9' '3' '4' '10' '10']
# 	 player num:  4 , round winner:  Batman
# 	 anchor:  none , busted:  Batman
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays pass
# place: ['3', '3', '3']
# 	 ['2' '5' '6' '7' 'J' 'J' 'J' 'K' 'Q' 'Q' '4' '4' 'Q' '5']
# 	 player num:  4 , round winner:  Batman
# 	 anchor:  Ironman , busted:  Batman
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays bust
# place: ['3', '3', '3']
# 	 ['10' '6' '7' '8' '8' '9' 'A' 'A' 'J' 'Q' '3' '3' '3']
# 	 player num:  4 , round winner:  Batman
# 	 anchor:  Ironman , busted:  Batman
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# ROUND  15
# first player: Batman
# place:  ['J'] call:  J
# Human - yolo , plays lie
# place: ['J', 'Q']
# 	 ['10' '6' '7' '8' '8' '9' 'A' 'A' 'J' '3' '3' '3']
# 	 player num:  4 , round winner:  Batman
# 	 anchor:  none , busted:  Batman
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays lie
# place: ['J', 'Q', '6']
# 	 ['2' '2' '5' '5' '8' 'K' 'K' 'K' '8' '2' '7' '6' '10']
# 	 player num:  4 , round winner:  Batman
# 	 anchor:  none , busted:  Batman
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['J', 'Q', '6']
# 	 ['4' '7' '9' 'A' '9' 'A' '9' '3' '4' '10' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  16
# first player: Ironman
# place:  ['A'] call:  A
# Batman - yolo , plays pass
# place: ['A']
# 	 ['2' '5' '6' '7' 'J' 'J' 'K' 'Q' 'Q' '4' '4' 'Q' '5']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays bust
# place: ['A']
# 	 ['10' '6' '7' '8' '8' '9' 'A' 'A' 'J' '3' '3' '3' 'A']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# ROUND  17
# first player: Thanos
# place:  ['5'] call:  6
# Ironman - thinker , plays bust
# place: ['5']
# 	 ['4' '7' '9' 'A' '9' '9' '3' '4' '10' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  18
# first player: Ironman
# place:  ['7'] call:  7
# Batman - yolo , plays lie
# place: ['7', '5']
# 	 ['2' '5' '6' '7' 'J' 'J' 'K' 'Q' 'Q' '4' '4' 'Q']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays bust
# place: ['7', '5']
# 	 ['10' '6' '7' '8' '8' '9' 'A' 'A' 'J' '3' '3' '3' 'A']
# 	 player num:  4 , round winner:  Human
# 	 anchor:  none , busted:  Batman
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# ROUND  19
# first player: Human
# place:  ['J'] call:  6
# Thanos - thinker , plays true
# place: ['J', '6']
# 	 ['2' '2' '5' '8' 'K' 'K' 'K' '8' '2' '7' '10' 'J' 'Q' '6' '5']
# 	 player num:  4 , round winner:  Human
# 	 anchor:  none , busted:  Batman
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['J', '6']
# 	 ['4' '9' 'A' '9' '9' '3' '4' '10' '10' 'J' '6']
# 	 player num:  4 , round winner:  Batman
# 	 anchor:  none , busted:  Batman
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  20
# first player: Batman
# place:  ['2'] call:  2
# Human - yolo , plays bust
# place: ['2']
# 	 ['10' '6' '7' '8' '8' '9' 'A' 'A' '3' '3' '3' 'A' '2']
# 	 player num:  4 , round winner:  Batman
# 	 anchor:  none , busted:  Batman
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# ROUND  21
# first player: Batman
# place:  ['4'] call:  4
# Human - yolo , plays pass
# place: ['4']
# 	 ['10' '6' '7' '8' '8' '9' 'A' 'A' '3' '3' '3' 'A' '2']
# 	 player num:  4 , round winner:  Batman
# 	 anchor:  Batman , busted:  Batman
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays lie
# place: ['4', '5']
# 	 ['2' '2' '5' '8' 'K' 'K' 'K' '8' '2' '7' '10' 'J' 'Q' '6']
# 	 player num:  4 , round winner:  Batman
# 	 anchor:  Batman , busted:  Batman
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['4', '5']
# 	 ['4' '9' 'A' '9' '9' '3' '4' '10' '10' 'J' '6']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  22
# first player: Ironman
# place:  ['J'] call:  J
# Batman - yolo , plays true
# place: ['J', 'J']
# 	 ['5' '6' '7' 'J' 'K' 'Q' 'Q' '4' 'Q' '7' '5']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays pass
# place: ['J', 'J']
# 	 ['10' '6' '7' '8' '8' '9' 'A' 'A' '3' '3' '3' 'A' '2']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays true
# place: ['J', 'J', 'J']
# 	 ['2' '2' '5' '8' 'K' 'K' 'K' '8' '2' '7' '10' 'Q' '6' '4' '5']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['J', 'J', 'J']
# 	 ['4' '9' 'A' '9' '9' '3' '4' '10' '10' '6' 'J' 'J' 'J']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  23
# first player: Thanos
# place:  ['K'] call:  9
# Ironman - thinker , plays true
# place: ['K', '9']
# 	 ['4' 'A' '9' '9' '3' '4' '10' '10' '6' 'J' 'J' 'J']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays pass
# place: ['K', '9']
# 	 ['5' '6' '7' 'J' 'K' 'Q' 'Q' '4' 'Q' '7' '5']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays pass
# place: ['K', '9']
# 	 ['10' '6' '7' '8' '8' '9' 'A' 'A' '3' '3' '3' 'A' '2']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays lie
# place: ['K', '9', '4']
# 	 ['2' '2' '5' '8' 'K' 'K' '8' '2' '7' '10' 'Q' '6' '5']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['K', '9', '4']
# 	 ['4' 'A' '9' '9' '3' '4' '10' '10' '6' 'J' 'J' 'J']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  24
# first player: Ironman
# place:  ['9'] call:  9
# Batman - yolo , plays lie
# place: ['9', 'J']
# 	 ['5' '6' '7' 'K' 'Q' 'Q' '4' 'Q' '7' '5']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays true
# place: ['9', 'J', '9']
# 	 ['10' '6' '7' '8' '8' 'A' 'A' '3' '3' '3' 'A' '2']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays true
# place: ['9', 'J', '9', '9']
# 	 ['2' '2' '5' '8' 'K' 'K' '8' '2' '7' '10' 'Q' '6' '5' 'K' '4']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['9', 'J', '9', '9']
# 	 ['4' 'A' '9' '3' '4' '10' '10' '6' 'J' 'J' 'J' '9' 'J' '9' '9']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  25
# first player: Thanos
# place:  ['5'] call:  7
# Ironman - thinker , plays bust
# place: ['5']
# 	 ['4' 'A' '9' '3' '4' '10' '10' '6' 'J' 'J' 'J' '9' 'J' '9' '9']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  26
# first player: Ironman
# place:  ['10'] call:  10
# Batman - yolo , plays lie
# place: ['10', 'Q']
# 	 ['5' '6' '7' 'K' 'Q' 'Q' '4' '7' '5']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays true
# place: ['10', 'Q', '10']
# 	 ['6' '7' '8' '8' 'A' 'A' '3' '3' '3' 'A' '2']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays true
# place: ['10', 'Q', '10', '10']
# 	 ['2' '2' '5' '8' 'K' 'K' '8' '2' '7' 'Q' '6' 'K' '4' '5']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['10', 'Q', '10', '10']
# 	 ['4' 'A' '9' '3' '4' '10' '6' 'J' 'J' 'J' '9' 'J' '9' '9' '10' 'Q' '10'
#  '10']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  27
# first player: Thanos
# place:  ['Q'] call:  3
# Ironman - thinker , plays true
# place: ['Q', '3']
# 	 ['4' 'A' '9' '4' '10' '6' 'J' 'J' 'J' '9' 'J' '9' '9' '10' 'Q' '10' '10']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays lie
# place: ['Q', '3', '7']
# 	 ['5' '6' 'K' 'Q' 'Q' '4' '7' '5']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays true
# place: ['Q', '3', '7', '3']
# 	 ['6' '7' '8' '8' 'A' 'A' '3' '3' 'A' '2']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays lie
# place: ['Q', '3', '7', '3', 'K']
# 	 ['2' '2' '5' '8' 'K' '8' '2' '7' '6' 'K' '4' '5']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['Q', '3', '7', '3', 'K']
# 	 ['4' 'A' '9' '4' '10' '6' 'J' 'J' 'J' '9' 'J' '9' '9' '10' 'Q' '10' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  28
# first player: Ironman
# place:  ['6'] call:  6
# Batman - yolo , plays bust
# place: ['6']
# 	 ['5' '6' 'K' 'Q' 'Q' '4' '7' '5' '6']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  29
# first player: Thanos
# place:  ['2'] call:  6
# Ironman - thinker , plays bust
# place: ['2']
# 	 ['4' 'A' '9' '4' '10' 'J' 'J' 'J' '9' 'J' '9' '9' '10' 'Q' '10' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  30
# first player: Ironman
# place:  ['10'] call:  10
# Batman - yolo , plays pass
# place: ['10']
# 	 ['5' '6' 'K' 'Q' 'Q' '4' '7' '5' '6']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays pass
# place: ['10']
# 	 ['6' '7' '8' '8' 'A' 'A' '3' '3' 'A' '2']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays lie
# place: ['10', 'K']
# 	 ['2' '2' '5' '8' 'K' '8' '7' '6' '4' '5' 'Q' '3' '7' '3' 'K' '2']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays true
# place: ['10', 'K', '10']
# 	 ['4' 'A' '9' '4' 'J' 'J' 'J' '9' 'J' '9' '9' 'Q' '10' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays lie
# place: ['10', 'K', '10', 'Q']
# 	 ['5' '6' 'K' 'Q' '4' '7' '5' '6']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays lie
# place: ['10', 'K', '10', 'Q', 'A']
# 	 ['6' '7' '8' '8' 'A' 'A' '3' '3' '2']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays lie
# place: ['10', 'K', '10', 'Q', 'A', 'K']
# 	 ['2' '2' '5' '8' 'K' '8' '7' '6' '4' '5' 'Q' '3' '7' '3' '2']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['10', 'K', '10', 'Q', 'A', 'K']
# 	 ['4' 'A' '9' '4' 'J' 'J' 'J' '9' 'J' '9' '9' 'Q' '10' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  31
# first player: Ironman
# place:  ['10'] call:  10
# Batman - yolo , plays lie
# place: ['10', '6']
# 	 ['5' '6' 'K' 'Q' '4' '7' '5']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays pass
# place: ['10', '6']
# 	 ['6' '7' '8' '8' 'A' 'A' '3' '3' '2']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays true
# place: ['10', '6', '10']
# 	 ['2' '2' '5' '8' 'K' '8' '7' '6' '4' '5' 'Q' '3' '7' '3' '2' 'K' '10' 'Q'
#  'A' 'K']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['10', '6', '10']
# 	 ['4' 'A' '9' '4' 'J' 'J' 'J' '9' 'J' '9' '9' 'Q' '10' '10' '6' '10']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  32
# first player: Thanos
# place:  ['2'] call:  10
# Ironman - thinker , plays true
# place: ['2', '10']
# 	 ['4' 'A' '9' '4' 'J' 'J' 'J' '9' 'J' '9' '9' 'Q' '10' '6' '10']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays pass
# place: ['2', '10']
# 	 ['5' '6' 'K' 'Q' '4' '7' '5']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays lie
# place: ['2', '10', '3']
# 	 ['6' '7' '8' '8' 'A' 'A' '3' '2']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays true
# place: ['2', '10', '3', '10']
# 	 ['2' '5' '8' 'K' '8' '7' '6' '4' '5' 'Q' '3' '7' '3' '2' 'K' 'Q' 'A' 'K']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['2', '10', '3', '10']
# 	 ['4' 'A' '9' '4' 'J' 'J' 'J' '9' 'J' '9' '9' 'Q' '10' '6' '10' '2' '10'
#  '3' '10']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  33
# first player: Thanos
# place:  ['5'] call:  9
# Ironman - thinker , plays true
# place: ['5', '9']
# 	 ['4' 'A' '4' 'J' 'J' 'J' '9' 'J' '9' '9' 'Q' '10' '6' '10' '2' '10' '3'
#  '10']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays lie
# place: ['5', '9', 'K']
# 	 ['5' '6' 'Q' '4' '7' '5']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays lie
# place: ['5', '9', 'K', '8']
# 	 ['6' '7' '8' 'A' 'A' '3' '2']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays lie
# place: ['5', '9', 'K', '8', 'A']
# 	 ['2' '5' '8' 'K' '8' '7' '6' '4' 'Q' '3' '7' '3' '2' 'K' 'Q' 'K']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['5', '9', 'K', '8', 'A']
# 	 ['4' 'A' '4' 'J' 'J' 'J' '9' 'J' '9' '9' 'Q' '10' '6' '10' '2' '10' '3'
#  '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  34
# first player: Ironman
# place:  ['10'] call:  10
# Batman - yolo , plays lie
# place: ['10', '7']
# 	 ['5' '6' 'Q' '4' '5']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays pass
# place: ['10', '7']
# 	 ['6' '7' '8' 'A' 'A' '3' '2']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays lie
# place: ['10', '7', '9']
# 	 ['2' '5' '8' 'K' '8' '7' '6' '4' 'Q' '3' '7' '3' '2' 'K' 'Q' 'K' '5' 'K'
#  '8' 'A']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['10', '7', '9']
# 	 ['4' 'A' '4' 'J' 'J' 'J' '9' 'J' '9' '9' 'Q' '10' '6' '2' '10' '3' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  35
# first player: Ironman
# place:  ['Q'] call:  Q
# Batman - yolo , plays bust
# place: ['Q']
# 	 ['5' '6' 'Q' '4' '5' 'Q']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  36
# first player: Thanos
# place:  ['Q'] call:  7
# Ironman - thinker , plays bust
# place: ['Q']
# 	 ['4' 'A' '4' 'J' 'J' 'J' '9' 'J' '9' '9' '10' '6' '2' '10' '3' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  37
# first player: Ironman
# place:  ['3'] call:  3
# Batman - yolo , plays bust
# place: ['3']
# 	 ['5' '6' 'Q' '4' '5' 'Q' '3']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  38
# first player: Thanos
# place:  ['5'] call:  6
# Ironman - thinker , plays true
# place: ['5', '6']
# 	 ['4' 'A' '4' 'J' 'J' 'J' '9' 'J' '9' '9' '10' '2' '10' '10']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays bust
# place: ['5', '6']
# 	 ['5' '6' 'Q' '4' '5' 'Q' '3' '5' '6']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  39
# first player: Thanos
# place:  ['K'] call:  6
# Ironman - thinker , plays bust
# place: ['K']
# 	 ['4' 'A' '4' 'J' 'J' 'J' '9' 'J' '9' '9' '10' '2' '10' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  40
# first player: Ironman
# place:  ['4'] call:  4
# Batman - yolo , plays lie
# place: ['4', 'Q']
# 	 ['5' '6' 'Q' '4' '5' '3' '5' '6']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays lie
# place: ['4', 'Q', '7']
# 	 ['6' '8' 'A' 'A' '3' '2']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays true
# place: ['4', 'Q', '7', '4']
# 	 ['2' '8' 'K' '8' '7' '6' '3' '7' '3' '2' 'Q' 'K' '5' 'K' '8' 'A' '10' '7'
#  '9' 'Q' 'K']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays true
# place: ['4', 'Q', '7', '4', '4']
# 	 ['A' 'J' 'J' 'J' '9' 'J' '9' '9' '10' '2' '10' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays true
# place: ['4', 'Q', '7', '4', '4', '4']
# 	 ['5' '6' 'Q' '5' '3' '5' '6']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays bust
# place: ['4', 'Q', '7', '4', '4', '4']
# 	 ['6' '8' 'A' 'A' '3' '2' '4' 'Q' '7' '4' '4' '4']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# ROUND  41
# first player: Thanos
# place:  ['2'] call:  9
# Ironman - thinker , plays true
# place: ['2', '9']
# 	 ['A' 'J' 'J' 'J' 'J' '9' '9' '10' '2' '10' '10']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays pass
# place: ['2', '9']
# 	 ['5' '6' 'Q' '5' '3' '5' '6']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays pass
# place: ['2', '9']
# 	 ['6' '8' 'A' 'A' '3' '2' '4' 'Q' '7' '4' '4' '4']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays true
# place: ['2', '9', '9']
# 	 ['2' '8' 'K' '8' '7' '6' '3' '7' '3' 'Q' 'K' '5' 'K' '8' 'A' '10' '7' 'Q'
#  'K']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays true
# place: ['2', '9', '9', '9']
# 	 ['A' 'J' 'J' 'J' 'J' '9' '10' '2' '10' '10']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays pass
# place: ['2', '9', '9', '9']
# 	 ['5' '6' 'Q' '5' '3' '5' '6']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays pass
# place: ['2', '9', '9', '9']
# 	 ['6' '8' 'A' 'A' '3' '2' '4' 'Q' '7' '4' '4' '4']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays lie
# place: ['2', '9', '9', '9', '8']
# 	 ['2' '8' 'K' '8' '7' '6' '3' '7' '3' 'Q' 'K' '5' 'K' 'A' '10' '7' 'Q' 'K']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['2', '9', '9', '9', '8']
# 	 ['A' 'J' 'J' 'J' 'J' '9' '10' '2' '10' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  42
# first player: Ironman
# place:  ['J'] call:  J
# Batman - yolo , plays bust
# place: ['J']
# 	 ['5' '6' 'Q' '5' '3' '5' '6' 'J']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  43
# first player: Thanos
# place:  ['9'] call:  2
# Ironman - thinker , plays true
# place: ['9', '2']
# 	 ['A' 'J' 'J' 'J' '9' '10' '10' '10']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays pass
# place: ['9', '2']
# 	 ['5' '6' 'Q' '5' '3' '5' '6' 'J']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays lie
# place: ['9', '2', '6']
# 	 ['8' 'A' 'A' '3' '2' '4' 'Q' '7' '4' '4' '4']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays true
# place: ['9', '2', '6', '2']
# 	 ['8' 'K' '8' '7' '6' '3' '7' '3' 'Q' 'K' '5' 'K' 'A' '10' '7' 'Q' 'K' '2'
#  '9' '9' '8']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['9', '2', '6', '2']
# 	 ['A' 'J' 'J' 'J' '9' '10' '10' '10' '9' '2' '6' '2']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  44
# first player: Thanos
# place:  ['K'] call:  5
# Ironman - thinker , plays bust
# place: ['K']
# 	 ['A' 'J' 'J' 'J' '9' '10' '10' '10' '9' '2' '6' '2']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  45
# first player: Ironman
# place:  ['A'] call:  A
# Batman - yolo , plays bust
# place: ['A']
# 	 ['5' '6' 'Q' '5' '3' '5' '6' 'J' 'A']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  46
# first player: Thanos
# place:  ['2'] call:  9
# Ironman - thinker , plays true
# place: ['2', '9']
# 	 ['J' 'J' 'J' '10' '10' '10' '9' '2' '6' '2']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays pass
# place: ['2', '9']
# 	 ['5' '6' 'Q' '5' '3' '5' '6' 'J' 'A']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays pass
# place: ['2', '9']
# 	 ['8' 'A' 'A' '3' '2' '4' 'Q' '7' '4' '4' '4']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays true
# place: ['2', '9', '9']
# 	 ['8' 'K' '8' '7' '6' '3' '7' '3' 'Q' '5' 'K' 'A' '10' '7' 'Q' 'K' '9' '8'
#  'K']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays true
# place: ['2', '9', '9', '9']
# 	 ['J' 'J' 'J' '10' '10' '10' '2' '6' '2']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays lie
# place: ['2', '9', '9', '9', 'Q']
# 	 ['5' '6' '5' '3' '5' '6' 'J' 'A']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays pass
# place: ['2', '9', '9', '9', 'Q']
# 	 ['8' 'A' 'A' '3' '2' '4' 'Q' '7' '4' '4' '4']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays true
# place: ['2', '9', '9', '9', 'Q', '9']
# 	 ['8' 'K' '8' '7' '6' '3' '7' '3' 'Q' '5' 'K' 'A' '10' '7' 'Q' 'K' '8' 'K']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['2', '9', '9', '9', 'Q', '9']
# 	 ['J' 'J' 'J' '10' '10' '10' '2' '6' '2' '2' '9' '9' '9' 'Q' '9']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  47
# first player: Thanos
# place:  ['K'] call:  5
# Ironman - thinker , plays bust
# place: ['K']
# 	 ['J' 'J' 'J' '10' '10' '10' '2' '6' '2' '2' '9' '9' '9' 'Q' '9']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  48
# first player: Ironman
# place:  ['2'] call:  2
# Batman - yolo , plays pass
# place: ['2']
# 	 ['5' '6' '5' '3' '5' '6' 'J' 'A']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays true
# place: ['2', '2']
# 	 ['8' 'A' 'A' '3' '4' 'Q' '7' '4' '4' '4']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays lie
# place: ['2', '2', '7']
# 	 ['8' 'K' '8' '6' '3' '7' '3' 'Q' '5' 'A' '10' '7' 'Q' 'K' '8' 'K' 'K']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays true
# place: ['2', '2', '7', '2']
# 	 ['J' 'J' 'J' '10' '10' '10' '6' '2' '9' '9' '9' 'Q' '9']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays pass
# place: ['2', '2', '7', '2']
# 	 ['5' '6' '5' '3' '5' '6' 'J' 'A']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays bust
# place: ['2', '2', '7', '2']
# 	 ['8' 'A' 'A' '3' '4' 'Q' '7' '4' '4' '4' '2' '2' '7' '2']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# ROUND  49
# first player: Thanos
# place:  ['K'] call:  Q
# Ironman - thinker , plays true
# place: ['K', 'Q']
# 	 ['J' 'J' 'J' '10' '10' '10' '6' '2' '9' '9' '9' '9']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays bust
# place: ['K', 'Q']
# 	 ['5' '6' '5' '3' '5' '6' 'J' 'A' 'K' 'Q']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  50
# first player: Thanos
# place:  ['5'] call:  3
# Ironman - thinker , plays bust
# place: ['5']
# 	 ['J' 'J' 'J' '10' '10' '10' '6' '2' '9' '9' '9' '9']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  51
# first player: Ironman
# place:  ['J'] call:  J
# Batman - yolo , plays bust
# place: ['J']
# 	 ['5' '6' '5' '3' '5' '6' 'J' 'A' 'K' 'Q' 'J']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  52
# first player: Thanos
# place:  ['K'] call:  A
# Ironman - thinker , plays bust
# place: ['K']
# 	 ['J' 'J' '10' '10' '10' '6' '2' '9' '9' '9' '9']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  53
# first player: Ironman
# place:  ['9'] call:  9
# Batman - yolo , plays bust
# place: ['9']
# 	 ['5' '6' '5' '3' '5' '6' 'J' 'A' 'K' 'Q' 'J' '9']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  54
# first player: Thanos
# place:  ['6'] call:  A
# Ironman - thinker , plays bust
# place: ['6']
# 	 ['J' 'J' '10' '10' '10' '6' '2' '9' '9' '9']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  55
# first player: Ironman
# place:  ['9'] call:  9
# Batman - yolo , plays true
# place: ['9', '9']
# 	 ['5' '6' '5' '3' '5' '6' 'J' 'A' 'K' 'Q' 'J']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays lie
# place: ['9', '9', '7']
# 	 ['8' 'A' 'A' '3' '4' 'Q' '7' '4' '4' '4' '2' '2' '2']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays lie
# place: ['9', '9', '7', '8']
# 	 ['8' '8' '3' '7' '3' 'Q' 'A' '10' '7' 'Q' 'K' 'K' '5' 'K' '6']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays true
# place: ['9', '9', '7', '8', '9']
# 	 ['J' 'J' '10' '10' '10' '6' '2' '9']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays pass
# place: ['9', '9', '7', '8', '9']
# 	 ['5' '6' '5' '3' '5' '6' 'J' 'A' 'K' 'Q' 'J']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays bust
# place: ['9', '9', '7', '8', '9']
# 	 ['8' 'A' 'A' '3' '4' 'Q' '7' '4' '4' '4' '2' '2' '2' '9' '9' '7' '8' '9']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# ROUND  56
# first player: Thanos
# place:  ['5'] call:  2
# Ironman - thinker , plays true
# place: ['5', '2']
# 	 ['J' 'J' '10' '10' '10' '6' '9']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays pass
# place: ['5', '2']
# 	 ['5' '6' '5' '3' '5' '6' 'J' 'A' 'K' 'Q' 'J']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays pass
# place: ['5', '2']
# 	 ['8' 'A' 'A' '3' '4' 'Q' '7' '4' '4' '4' '2' '2' '2' '9' '9' '7' '8' '9']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays lie
# place: ['5', '2', 'K']
# 	 ['8' '8' '3' '7' '3' 'Q' 'A' '10' '7' 'Q' 'K' 'K' '6']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['5', '2', 'K']
# 	 ['J' 'J' '10' '10' '10' '6' '9']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  57
# first player: Ironman
# place:  ['J'] call:  J
# Batman - yolo , plays bust
# place: ['J']
# 	 ['5' '6' '5' '3' '5' '6' 'J' 'A' 'K' 'Q' 'J' 'J']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  58
# first player: Thanos
# place:  ['7'] call:  Q
# Ironman - thinker , plays bust
# place: ['7']
# 	 ['J' '10' '10' '10' '6' '9']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  59
# first player: Ironman
# place:  ['6'] call:  6
# Batman - yolo , plays true
# place: ['6', '6']
# 	 ['5' '5' '3' '5' '6' 'J' 'A' 'K' 'Q' 'J' 'J']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays bust
# place: ['6', '6']
# 	 ['8' 'A' 'A' '3' '4' 'Q' '7' '4' '4' '4' '2' '2' '2' '9' '9' '7' '8' '9'
#  '6' '6']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# ROUND  60
# first player: Thanos
# place:  ['3'] call:  9
# Ironman - thinker , plays true
# place: ['3', '9']
# 	 ['J' '10' '10' '10']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# Batman - yolo , plays bust
# place: ['3', '9']
# 	 ['5' '5' '3' '5' '6' 'J' 'A' 'K' 'Q' 'J' 'J' '3' '9']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  61
# first player: Thanos
# place:  ['2'] call:  8
# Ironman - thinker , plays bust
# place: ['2']
# 	 ['J' '10' '10' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  62
# first player: Ironman
# place:  ['J'] call:  J
# Batman - yolo , plays pass
# place: ['J']
# 	 ['5' '5' '3' '5' '6' 'J' 'A' 'K' 'Q' 'J' 'J' '3' '9']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays lie
# place: ['J', '4']
# 	 ['8' 'A' 'A' '3' '4' 'Q' '7' '4' '4' '2' '2' '2' '9' '9' '7' '8' '9' '6'
#  '6']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays lie
# place: ['J', '4', '7']
# 	 ['8' '8' '3' 'Q' 'A' '10' 'Q' 'K' 'K' '6' '5' 'K' '7' '2']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Thanos' 'Ironman' 'Batman' 'Human']
# Ironman - thinker , plays bust
# place: ['J', '4', '7']
# 	 ['10' '10' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  63
# first player: Ironman
# place:  ['10'] call:  10
# Batman - yolo , plays bust
# place: ['10']
# 	 ['5' '5' '3' '5' '6' 'J' 'A' 'K' 'Q' 'J' 'J' '3' '9' '10']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  64
# first player: Thanos
# place:  ['5'] call:  3
# Ironman - thinker , plays bust
# place: ['5']
# 	 ['10' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  65
# first player: Ironman
# place:  ['10'] call:  10
# Batman - yolo , plays bust
# place: ['10']
# 	 ['5' '5' '3' '5' '6' 'J' 'A' 'K' 'Q' 'J' 'J' '3' '9' '10' '10']
# 	 player num:  4 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# ROUND  66
# first player: Thanos
# place:  ['3'] call:  4
# Ironman - thinker , plays bust
# place: ['3']
# 	 ['10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  [] , remain: ['Ironman' 'Batman' 'Human' 'Thanos']
# ROUND  67
# first player: Ironman
# place:  ['10'] call:  10
# Batman - yolo , plays pass
# place: ['10']
# 	 ['5' '5' '3' '5' '6' 'J' 'A' 'K' 'Q' 'J' 'J' '3' '9' '10' '10']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Batman' 'Human' 'Thanos' 'Ironman']
# Human - yolo , plays pass
# place: ['10']
# 	 ['8' 'A' 'A' '3' '4' 'Q' '7' '4' '4' '2' '2' '2' '9' '9' '7' '8' '9' '6'
#  '6']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  [] , remain: ['Human' 'Thanos' 'Ironman' 'Batman']
# Thanos - thinker , plays true
# place: ['10', '10']
# 	 ['8' '8' 'Q' 'A' 'Q' 'K' 'K' '6' 'K' '7' '2' 'J' '4' '7' '5' '3']
# 	 player num:  4 , round winner:  Ironman
# 	 anchor:  Ironman , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays pass
# place: ['10', '10']
# 	 ['5' '5' '3' '5' '6' 'J' 'A' 'K' 'Q' 'J' 'J' '3' '9' '10' '10']
# 	 player num:  3 , round winner:  Ironman
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays pass
# place: ['10', '10']
# 	 ['8' 'A' 'A' '3' '4' 'Q' '7' '4' '4' '2' '2' '2' '9' '9' '7' '8' '9' '6'
#  '6']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# ROUND  68
# first player: Thanos
# place:  ['2'] call:  6
# Batman - yolo , plays bust
# place: ['2']
# 	 ['5' '5' '3' '5' '6' 'J' 'A' 'K' 'Q' 'J' 'J' '3' '9' '10' '10']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# ROUND  69
# first player: Batman
# place:  ['5'] call:  5
# Human - yolo , plays bust
# place: ['5']
# 	 ['8' 'A' 'A' '3' '4' 'Q' '7' '4' '4' '2' '2' '2' '9' '9' '7' '8' '9' '6'
#  '6' '5']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# ...
# 	 player num:  3 , round winner:  Human
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays true
# place: ['8', '3', '3', '3']
# 	 ['A' '4' '4' '4' 'Q' 'Q' '9' 'A' '6' '2' '6' '9' '5']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# Thanos - thinker , plays true
# place: ['8', '3', '3', '3', '3']
# 	 ['8' '2' '7' '2' '10' '7' 'Q' '8' 'K' '7']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays lie
# place: ['8', '3', '3', '3', '3', 'A']
# 	 ['5' '5' '7' '5']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays lie
# place: ['8', '3', '3', '3', '3', 'A', '9']
# 	 ['A' '4' '4' '4' 'Q' 'Q' '9' 'A' '6' '2' '6' '5']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# Thanos - thinker , plays lie
# place: ['8', '3', '3', '3', '3', 'A', '9', '8']
# 	 ['2' '7' '2' '10' '7' 'Q' '8' 'K' '7']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays pass
# place: ['8', '3', '3', '3', '3', 'A', '9', '8']
# 	 ['5' '5' '7' '5']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays pass
# place: ['8', '3', '3', '3', '3', 'A', '9', '8']
# 	 ['A' '4' '4' '4' 'Q' 'Q' '9' 'A' '6' '2' '6' '5']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# ROUND  102
# first player: Thanos
# place:  ['K'] call:  J
# Batman - yolo , plays pass
# place: ['K']
# 	 ['5' '5' '7' '5']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays bust
# place: ['K']
# 	 ['A' '4' '4' '4' 'Q' 'Q' '9' 'A' '6' '2' '6' '5']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# ROUND  103
# first player: Human
# place:  ['Q'] call:  9
# Thanos - thinker , plays lie
# place: ['Q', '10']
# 	 ['2' '7' '2' '7' 'Q' '8' '7' 'K']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays bust
# place: ['Q', '10']
# 	 ['5' '5' '7' '5']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# ROUND  104
# first player: Batman
# place:  ['5'] call:  5
# Human - yolo , plays true
# place: ['5', '5']
# 	 ['A' '4' '4' '4' 'Q' '9' 'A' '6' '2' '6']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# Thanos - thinker , plays lie
# place: ['5', '5', '8']
# 	 ['2' '7' '2' '7' 'Q' '7' 'K' 'Q' '10']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays true
# place: ['5', '5', '8', '5']
# 	 ['7' '5']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays bust
# place: ['5', '5', '8', '5']
# 	 ['A' '4' '4' '4' 'Q' '9' 'A' '6' '2' '6' '5' '5' '8' '5']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# ROUND  105
# first player: Thanos
# place:  ['2'] call:  6
# Batman - yolo , plays pass
# place: ['2']
# 	 ['7' '5']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays bust
# place: ['2']
# 	 ['A' '4' '4' '4' 'Q' '9' 'A' '6' '2' '6' '5' '5' '8' '5']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# ROUND  106
# first player: Human
# place:  ['8'] call:  10
# Thanos - thinker , plays true
# place: ['8', '10']
# 	 ['7' '2' '7' 'Q' '7' 'K' 'Q' '2']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays bust
# place: ['8', '10']
# 	 ['7' '5' '8' '10']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# ROUND  107
# first player: Thanos
# place:  ['2'] call:  5
# Batman - yolo , plays lie
# place: ['2', '10']
# 	 ['7' '5' '8']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays bust
# place: ['2', '10']
# 	 ['A' '4' '4' '4' 'Q' '9' 'A' '6' '2' '6' '5' '5' '5']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  none , busted:  Batman
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# ROUND  108
# first player: Human
# place:  ['A'] call:  8
# Thanos - thinker , plays lie
# place: ['A', '7']
# 	 ['7' 'Q' '7' 'K' 'Q' '2']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  none , busted:  Batman
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays lie
# place: ['A', '7', '7']
# 	 ['5' '8' '2' '10']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  none , busted:  Batman
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays pass
# place: ['A', '7', '7']
# 	 ['4' '4' '4' 'Q' '9' 'A' '6' '2' '6' '5' '5' '5']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  Batman , busted:  Batman
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# Thanos - thinker , plays lie
# place: ['A', '7', '7', 'Q']
# 	 ['7' 'Q' '7' 'K' '2']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  Batman , busted:  Batman
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays pass
# place: ['A', '7', '7', 'Q']
# 	 ['5' '8' '2' '10']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  Thanos , busted:  Batman
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays pass
# place: ['A', '7', '7', 'Q']
# 	 ['4' '4' '4' 'Q' '9' 'A' '6' '2' '6' '5' '5' '5']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  Thanos , busted:  Batman
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# ROUND  109
# first player: Thanos
# place:  ['7'] call:  5
# Batman - yolo , plays pass
# place: ['7']
# 	 ['5' '8' '2' '10']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  Thanos , busted:  Batman
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays lie
# place: ['7', 'A']
# 	 ['4' '4' '4' 'Q' '9' '6' '2' '6' '5' '5' '5']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  Thanos , busted:  Batman
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# Thanos - thinker , plays lie
# place: ['7', 'A', '2']
# 	 ['Q' '7' 'K']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  none , busted:  Batman
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays pass
# place: ['7', 'A', '2']
# 	 ['5' '8' '2' '10']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  Thanos , busted:  Batman
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays true
# place: ['7', 'A', '2', '5']
# 	 ['4' '4' '4' 'Q' '9' '6' '2' '6' '5' '5']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  Thanos , busted:  Batman
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# Thanos - thinker , plays lie
# place: ['7', 'A', '2', '5', 'Q']
# 	 ['7' 'K']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  none , busted:  Batman
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays bust
# place: ['7', 'A', '2', '5', 'Q']
# 	 ['5' '8' '2' '10']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# ROUND  110
# first player: Batman
# place:  ['8'] call:  8
# Human - yolo , plays pass
# place: ['8']
# 	 ['4' '4' '4' 'Q' '9' '6' '2' '6' '5' '5']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# Thanos - thinker , plays lie
# place: ['8', '7']
# 	 ['K' '7' 'A' '2' '5' 'Q']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays pass
# place: ['8', '7']
# 	 ['5' '2' '10']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays lie
# place: ['8', '7', '6']
# 	 ['4' '4' '4' 'Q' '9' '6' '2' '5' '5']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# Thanos - thinker , plays lie
# place: ['8', '7', '6', 'A']
# 	 ['K' '7' '2' '5' 'Q']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays bust
# place: ['8', '7', '6', 'A']
# 	 ['5' '2' '10']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# ROUND  111
# first player: Batman
# place:  ['10'] call:  10
# Human - yolo , plays pass
# place: ['10']
# 	 ['4' '4' '4' 'Q' '9' '6' '2' '5' '5']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# Thanos - thinker , plays lie
# place: ['10', '5']
# 	 ['K' '7' '2' 'Q' '8' '7' '6' 'A']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays pass
# place: ['10', '5']
# 	 ['5' '2']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays bust
# place: ['10', '5']
# 	 ['4' '4' '4' 'Q' '9' '6' '2' '5' '5']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# ROUND  112
# first player: Human
# place:  ['5'] call:  J
# Thanos - thinker , plays lie
# place: ['5', '6']
# 	 ['K' '7' '2' 'Q' '8' '7' 'A' '10' '5']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays pass
# place: ['5', '6']
# 	 ['5' '2']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays lie
# place: ['5', '6', '5']
# 	 ['4' '4' '4' 'Q' '9' '6' '2']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# Thanos - thinker , plays lie
# place: ['5', '6', '5', 'K']
# 	 ['7' '2' 'Q' '8' '7' 'A' '10' '5']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays pass
# place: ['5', '6', '5', 'K']
# 	 ['5' '2']
# 	 player num:  3 , round winner:  Human
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays pass
# place: ['5', '6', '5', 'K']
# 	 ['4' '4' '4' 'Q' '9' '6' '2']
# 	 player num:  3 , round winner:  Thanos
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# ROUND  113
# first player: Thanos
# place:  ['7'] call:  2
# Batman - yolo , plays bust
# place: ['7']
# 	 ['5' '2']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# ROUND  114
# first player: Batman
# place:  ['2'] call:  2
# Human - yolo , plays lie
# place: ['2', 'Q']
# 	 ['4' '4' '4' '9' '6' '2']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# Thanos - thinker , plays true
# place: ['2', 'Q', '2']
# 	 ['Q' '8' '7' 'A' '10' '5' '7']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Thanos' 'Batman' 'Human']
# Batman - yolo , plays lie
# place: ['2', 'Q', '2', '5']
# 	 []
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Batman' 'Human' 'Thanos']
# Human - yolo , plays pass
# place: ['2', 'Q', '2', '5']
# 	 ['4' '4' '4' '9' '6' '2']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  ['Ironman'] , remain: ['Human' 'Thanos' 'Batman']
# Thanos - thinker , plays lie
# place: ['2', 'Q', '2', '5', '10']
# 	 ['Q' '8' '7' 'A' '5' '7']
# 	 player num:  3 , round winner:  Batman
# 	 anchor:  Batman , busted:  Thanos
# 	 winner:  ['Ironman', 'Batman'] , remain: ['Thanos' 'Human']
# Human - yolo , plays true
# place: ['2', 'Q', '2', '5', '10', '2']
# 	 ['4' '4' '4' '9' '6']
# 	 player num:  2 , round winner:  Batman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman', 'Batman'] , remain: ['Human' 'Thanos']
# Thanos - thinker , plays lie
# place: ['2', 'Q', '2', '5', '10', '2', '7']
# 	 ['Q' '8' '7' 'A' '5']
# 	 player num:  2 , round winner:  Batman
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman', 'Batman'] , remain: ['Thanos' 'Human']
# Human - yolo , plays pass
# place: ['2', 'Q', '2', '5', '10', '2', '7']
# 	 ['4' '4' '4' '9' '6']
# 	 player num:  2 , round winner:  Thanos
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman', 'Batman'] , remain: ['Human' 'Thanos']
# ROUND  115
# first player: Thanos
# place:  ['7'] call:  2
# Human - yolo , plays pass
# place: ['7']
# 	 ['4' '4' '4' '9' '6']
# 	 player num:  2 , round winner:  Thanos
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman', 'Batman'] , remain: ['Human' 'Thanos']
# ROUND  116
# first player: Thanos
# place:  ['8'] call:  5
# Human - yolo , plays pass
# place: ['8']
# 	 ['4' '4' '4' '9' '6']
# 	 player num:  2 , round winner:  Thanos
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman', 'Batman'] , remain: ['Human' 'Thanos']
# ROUND  117
# first player: Thanos
# place:  ['A'] call:  7
# Human - yolo , plays bust
# place: ['A']
# 	 ['4' '4' '4' '9' '6']
# 	 player num:  2 , round winner:  Human
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman', 'Batman'] , remain: ['Human' 'Thanos']
# ROUND  118
# first player: Human
# place:  ['4'] call:  K
# Thanos - thinker , plays lie
# place: ['4', 'A']
# 	 ['Q' '5']
# 	 player num:  2 , round winner:  Human
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman', 'Batman'] , remain: ['Thanos' 'Human']
# Human - yolo , plays pass
# place: ['4', 'A']
# 	 ['4' '4' '9' '6']
# 	 player num:  2 , round winner:  Thanos
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman', 'Batman'] , remain: ['Human' 'Thanos']
# ROUND  119
# first player: Thanos
# place:  ['Q'] call:  J
# Human - yolo , plays pass
# place: ['Q']
# 	 ['4' '4' '9' '6']
# 	 player num:  2 , round winner:  Thanos
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman', 'Batman'] , remain: ['Human' 'Thanos']
# ROUND  120
# first player: Thanos
# place:  ['5'] call:  J
# Human - yolo , plays bust
# place: ['5']
# 	 ['4' '4' '9' '6']
# 	 player num:  2 , round winner:  Human
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman', 'Batman'] , remain: ['Human' 'Thanos']
# ROUND  121
# first player: Human
# place:  ['4'] call:  3
# Thanos - thinker , plays lie
# place: ['4', '5']
# 	 []
# 	 player num:  2 , round winner:  Human
# 	 anchor:  none , busted:  Thanos
# 	 winner:  ['Ironman', 'Batman'] , remain: ['Thanos' 'Human']
# Human - yolo , plays pass
# place: ['4', '5']
# 	 ['4' '9' '6']
# 	 player num:  2 , round winner:  Human
# 	 anchor:  Thanos , busted:  Thanos
# 	 winner:  ['Ironman', 'Batman', 'Thanos'] , remain: ['Human']

# %%
player[remain]
remain
player[busted_player]
# Out:
# array(['Human'], dtype='<U7')
# array([3], dtype=int64)
# 'Thanos'

# %%
player
player_num
card_count
anchor
winner
player[remain]
# Out:
# array(['Thanos', 'Ironman', 'Batman', 'Human'], dtype='<U7')
# 1
# [0, 0, 0, 3]
# ['Ironman', 'Batman', 'Thanos']
# array(['Human'], dtype='<U7')
